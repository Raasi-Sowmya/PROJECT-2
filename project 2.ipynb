# %%
#PROBLEM STATEMENT
#To collect title and price of books from Book Store Website

# %%
#DATA COLLECTION

# %%
import pandas as pd
import numpy as np
from requests import get
from bs4 import BeautifulSoup
import re

# %%
page=requests.get("http://books.toscrape.com/")

# %%
page
# Out:
# <Response [200]>

# %%
page.text
# Out:
# '<!DOCTYPE html>\n<!--[if lt IE 7]>      <html lang="en-us" class="no-js lt-ie9 lt-ie8 lt-ie7"> <![endif]-->\n<!--[if IE 7]>         <html lang="en-us" class="no-js lt-ie9 lt-ie8"> <![endif]-->\n<!--[if IE 8]>         <html lang="en-us" class="no-js lt-ie9"> <![endif]-->\n<!--[if gt IE 8]><!--> <html lang="en-us" class="no-js"> <!--<![endif]-->\n    <head>\n        <title>\n    All products | Books to Scrape - Sandbox\n</title>\n\n        <meta http-equiv="content-type" content="text/html; charset=UTF-8" />\n        <meta name="created" content="24th Jun 2016 09:29" />\n        <meta name="description" content="" />\n        <meta name="viewport" content="width=device-width" />\n        <meta name="robots" content="NOARCHIVE,NOCACHE" />\n\n        <!-- Le HTML5 shim, for IE6-8 support of HTML elements -->\n        <!--[if lt IE 9]>\n        <script src="//html5shim.googlecode.com/svn/trunk/html5.js"></script>\n        <![endif]-->\n\n        \n            <link rel="shortcut icon" hr
# ...

# %%
soup=BeautifulSoup(page.text)
soup
# Out:
# <!DOCTYPE html>
# <!--[if lt IE 7]>      <html lang="en-us" class="no-js lt-ie9 lt-ie8 lt-ie7"> <![endif]--><!--[if IE 7]>         <html lang="en-us" class="no-js lt-ie9 lt-ie8"> <![endif]--><!--[if IE 8]>         <html lang="en-us" class="no-js lt-ie9"> <![endif]--><!--[if gt IE 8]><!--><html class="no-js" lang="en-us"> <!--<![endif]-->
# <head>
# <title>
#     All products | Books to Scrape - Sandbox
# </title>
# <meta content="text/html; charset=utf-8" http-equiv="content-type"/>
# <meta content="24th Jun 2016 09:29" name="created"/>
# <meta content="" name="description"/>
# <meta content="width=device-width" name="viewport"/>
# <meta content="NOARCHIVE,NOCACHE" name="robots"/>
# <!-- Le HTML5 shim, for IE6-8 support of HTML elements -->
# <!--[if lt IE 9]>
#         <script src="//html5shim.googlecode.com/svn/trunk/html5.js"></script>
#         <![endif]-->
# <link href="static/oscar/favicon.ico" rel="shortcut icon"/>
# ...

# %%
#DATA CLEANING

# %%
for link in soup.find_all("a"):
    print(link.get("href"))
# Out:
# index.html
# index.html
# catalogue/category/books_1/index.html
# catalogue/category/books/travel_2/index.html
# catalogue/category/books/mystery_3/index.html
# catalogue/category/books/historical-fiction_4/index.html
# catalogue/category/books/sequential-art_5/index.html
# catalogue/category/books/classics_6/index.html
# catalogue/category/books/philosophy_7/index.html
# catalogue/category/books/romance_8/index.html
# catalogue/category/books/womens-fiction_9/index.html
# catalogue/category/books/fiction_10/index.html
# catalogue/category/books/childrens_11/index.html
# catalogue/category/books/religion_12/index.html
# catalogue/category/books/nonfiction_13/index.html
# catalogue/category/books/music_14/index.html
# catalogue/category/books/default_15/index.html
# catalogue/category/books/science-fiction_16/index.html
# catalogue/category/books/sports-and-games_17/index.html
# catalogue/category/books/add-a-comment_18/index.html
# catalogue/category/books/fantasy_19/index.html
# ...

# %%
print(soup.get_text())
# Out:
#
#
#
#     All products | Books to Scrape - Sandbox
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Books to Scrape We love being scraped!
#
#
#
#
#
#
#
#
# Home
#
# All products
#
#
#
#
#
#
#
#
#
#
#                                 Books
#
#
#
#
#
#
#                                 Travel
#
#
#
#
#
#
#                                 Mystery
#
#
#
#
#
#
#                                 Historical Fiction
#
#
#
#
#
#
#                                 Sequential Art
#
#
#
#
#
#
#                                 Classics
#
#
#
#
#
#
#                                 Philosophy
#
#
#
#
#
#
#                                 Romance
#
#
#
#
#
#
#                                 Womens Fiction
#
#
#
#
#
#
#                                 Fiction
#
#
#
#
#
#
#                                 Childrens
#
#
#
#
#
#
#                                 Religion
#
#
#
#
#
#
#                                 Nonfiction
#
#
#
#
#
#
#                                 Music
#
#
#
#
#
#
# ...

# %%
print(soup.prettify()[0:1000])
# Out:
# <!DOCTYPE html>
# <!--[if lt IE 7]>      <html lang="en-us" class="no-js lt-ie9 lt-ie8 lt-ie7"> <![endif]-->
# <!--[if IE 7]>         <html lang="en-us" class="no-js lt-ie9 lt-ie8"> <![endif]-->
# <!--[if IE 8]>         <html lang="en-us" class="no-js lt-ie9"> <![endif]-->
# <!--[if gt IE 8]><!-->
# <html class="no-js" lang="en-us">
#  <!--<![endif]-->
#  <head>
#   <title>
#    All products | Books to Scrape - Sandbox
#   </title>
#   <meta content="text/html; charset=utf-8" http-equiv="content-type"/>
#   <meta content="24th Jun 2016 09:29" name="created"/>
#   <meta content="" name="description"/>
#   <meta content="width=device-width" name="viewport"/>
#   <meta content="NOARCHIVE,NOCACHE" name="robots"/>
#   <!-- Le HTML5 shim, for IE6-8 support of HTML elements -->
#   <!--[if lt IE 9]>
#         <script src="//html5shim.googlecode.com/svn/trunk/html5.js"></script>
#         <![endif]-->
#   <link href="static/oscar/favicon.ico" rel="shortcut icon"/>
# ...

# %%
for link in soup.find_all("a",attrs={"href":re.compile("^catalogue")}):
    print(link)
type(link)
# Out:
# <a href="catalogue/category/books_1/index.html">
#
#                                 Books
#
#                         </a>
# <a href="catalogue/category/books/travel_2/index.html">
#
#                                 Travel
#
#                         </a>
# <a href="catalogue/category/books/mystery_3/index.html">
#
#                                 Mystery
#
#                         </a>
# <a href="catalogue/category/books/historical-fiction_4/index.html">
#
#                                 Historical Fiction
#
#                         </a>
# <a href="catalogue/category/books/sequential-art_5/index.html">
#
#                                 Sequential Art
#
#                         </a>
# <a href="catalogue/category/books/classics_6/index.html">
#
#                                 Classics
#
#                         </a>
# <a href="catalogue/category/books/philosophy_7/index.html">
#
#                                 Philosophy
#
#                         </a>
# ...

# %%
p=soup.find_all("a",attrs={"title":re.compile("A Light in the Attic")})
p
# Out:
# [<a href="catalogue/a-light-in-the-attic_1000/index.html" title="A Light in the Attic">A Light in the ...</a>]

# %%
TITTLE=[]
for n in soup.find_all("a"):
    t=n.get("title")
    if t!=None:
        TITTLE.append(t)
        print(t)
# Out:
# A Light in the Attic
# Tipping the Velvet
# Soumission
# Sharp Objects
# Sapiens: A Brief History of Humankind
# The Requiem Red
# The Dirty Little Secrets of Getting Your Dream Job
# The Coming Woman: A Novel Based on the Life of the Infamous Feminist, Victoria Woodhull
# The Boys in the Boat: Nine Americans and Their Epic Quest for Gold at the 1936 Berlin Olympics
# The Black Maria
# Starving Hearts (Triangular Trade Trilogy, #1)
# Shakespeare's Sonnets
# Set Me Free
# Scott Pilgrim's Precious Little Life (Scott Pilgrim #1)
# Rip it Up and Start Again
# Our Band Could Be Your Life: Scenes from the American Indie Underground, 1981-1991
# Olio
# Mesaerion: The Best Science Fiction Stories 1800-1849
# Libertarianism for Beginners
# It's Only the Himalayas

# %%
data=soup.find_all('p',class_="price_color")
data
# Out:
# [<p class="price_color">Â£51.77</p>,
#  <p class="price_color">Â£53.74</p>,
#  <p class="price_color">Â£50.10</p>,
#  <p class="price_color">Â£47.82</p>,
#  <p class="price_color">Â£54.23</p>,
#  <p class="price_color">Â£22.65</p>,
#  <p class="price_color">Â£33.34</p>,
#  <p class="price_color">Â£17.93</p>,
#  <p class="price_color">Â£22.60</p>,
#  <p class="price_color">Â£52.15</p>,
#  <p class="price_color">Â£13.99</p>,
#  <p class="price_color">Â£20.66</p>,
#  <p class="price_color">Â£17.46</p>,
#  <p class="price_color">Â£52.29</p>,
#  <p class="price_color">Â£35.02</p>,
#  <p class="price_color">Â£57.25</p>,
#  <p class="price_color">Â£23.88</p>,
#  <p class="price_color">Â£37.59</p>,
#  <p class="price_color">Â£51.33</p>,
#  <p class="price_color">Â£45.17</p>]

# %%
type(PRICES)
# Out:
# list

# %%
re.findall(r"\£\d+\.\d+",data[0].text)[0]
# Out:
# '£51.77'

# %%
PRICES=[]
for i in data:
     
    a=re.findall(r"\£\d+\.\d+",i.text)[0]
    print(a)
    PRICES.append(a)
# Out:
# £51.77
# £53.74
# £50.10
# £47.82
# £54.23
# £22.65
# £33.34
# £17.93
# £22.60
# £52.15
# £13.99
# £20.66
# £17.46
# £52.29
# £35.02
# £57.25
# £23.88
# £37.59
# £51.33
# £45.17

# %%
len(PRICES)
# Out:
# 20

# %%
TITTLE=[]
PRICES=[]
u=[]
a="http://books.toscrape.com/catalogue/page-"+str()
for r in range(1,51):
    print(a+str(r)+(".html"))
    results=requests.get("http://books.toscrape.com/")
    soup=BeautifulSoup(results.text,'html.parser')
    soup.prettify()
    p=soup.find_all("a",attrs={"title":re.compile("A Light in the Attic")})
    data=soup.find_all("p",class_="price_color")
    
    
    #TITTLES
    for n in soup.find_all("a"):
        t=n.get("title")
        if t!=None:
            TITTLE.append(t) 
    
    #PRICES
    for i in data:
        a=re.findall(r"\£\d+\.\d+",i.text)[0]
        if a:
            #print(a)
            PRICES.append(a)
        
    print(len(TITTLE))
    print(len(PRICES))
# Out:
# http://books.toscrape.com/catalogue/page-1.html
# 20
# 20
# £45.172.html
# 40
# 40
# £45.173.html
# 60
# 60
# £45.174.html
# 80
# 80
# £45.175.html
# 100
# 100
# £45.176.html
# 120
# 120
# £45.177.html
# 140
# 140
# £45.178.html
# 160
# 160
# £45.179.html
# 180
# 180
# £45.1710.html
# 200
# 200
# £45.1711.html
# 220
# 220
# £45.1712.html
# 240
# 240
# £45.1713.html
# 260
# 260
# £45.1714.html
# 280
# 280
# £45.1715.html
# 300
# 300
# £45.1716.html
# 320
# 320
# £45.1717.html
# 340
# 340
# £45.1718.html
# 360
# 360
# £45.1719.html
# 380
# 380
# £45.1720.html
# 400
# 400
# £45.1721.html
# 420
# 420
# £45.1722.html
# 440
# 440
# £45.1723.html
# 460
# 460
# £45.1724.html
# 480
# 480
# £45.1725.html
# 500
# 500
# £45.1726.html
# 520
# 520
# £45.1727.html
# 540
# 540
# £45.1728.html
# 560
# 560
# £45.1729.html
# 580
# 580
# £45.1730.html
# 600
# 600
# £45.1731.html
# 620
# 620
# £45.1732.html
# 640
# 640
# £45.1733.html
# 660
# 660
# £45.1734.html
# 680
# 680
# £45.1735.html
# 700
# 700
# ...

# %%
BOOKS={"Tittle":TITTLE,
       "PRICES":PRICES}
BOOKS
# Out:
# {'Tittle': ['A Light in the Attic',
#   'Tipping the Velvet',
#   'Soumission',
#   'Sharp Objects',
#   'Sapiens: A Brief History of Humankind',
#   'The Requiem Red',
#   'The Dirty Little Secrets of Getting Your Dream Job',
#   'The Coming Woman: A Novel Based on the Life of the Infamous Feminist, Victoria Woodhull',
#   'The Boys in the Boat: Nine Americans and Their Epic Quest for Gold at the 1936 Berlin Olympics',
#   'The Black Maria',
#   'Starving Hearts (Triangular Trade Trilogy, #1)',
#   "Shakespeare's Sonnets",
#   'Set Me Free',
#   "Scott Pilgrim's Precious Little Life (Scott Pilgrim #1)",
#   'Rip it Up and Start Again',
#   'Our Band Could Be Your Life: Scenes from the American Indie Underground, 1981-1991',
#   'Olio',
#   'Mesaerion: The Best Science Fiction Stories 1800-1849',
#   'Libertarianism for Beginners',
#   "It's Only the Himalayas",
#   'A Light in the Attic',
#   'Tipping the Velvet',
#   'Soumission',
#   'Sharp Objects',
# ...

# %%
result1=pd.DataFrame(BOOKS)
result1
# Out:
#                                                 Tittle  PRICES
# 0                                 A Light in the Attic  £51.77
# 1                                   Tipping the Velvet  £53.74
# 2                                           Soumission  £50.10
# 3                                        Sharp Objects  £47.82
# 4                Sapiens: A Brief History of Humankind  £54.23
# ..                                                 ...     ...
# 995  Our Band Could Be Your Life: Scenes from the A...  £57.25
# 996                                               Olio  £23.88
# 997  Mesaerion: The Best Science Fiction Stories 18...  £37.59
# 998                       Libertarianism for Beginners  £51.33
# 999                            It's Only the Himalayas  £45.17
#
# [1000 rows x 2 columns]

# %%
#DATA ANALYSIS

# %%
result1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Tittle  1000 non-null   object
#  1   PRICES  1000 non-null   object
# dtypes: object(2)
# memory usage: 15.8+ KB

# %%
result1.groupby(by="Tittle").count()
# Out:
#                                                     PRICES
# Tittle
# A Light in the Attic                                    50
# It's Only the Himalayas                                 50
# Libertarianism for Beginners                            50
# Mesaerion: The Best Science Fiction Stories 180...      50
# Olio                                                    50
# Our Band Could Be Your Life: Scenes from the Am...      50
# Rip it Up and Start Again                               50
# Sapiens: A Brief History of Humankind                   50
# Scott Pilgrim's Precious Little Life (Scott Pil...      50
# Set Me Free                                             50
# Shakespeare's Sonnets                                   50
# Sharp Objects                                           50
# Soumission                                              50
# Starving Hearts (Triangular Trade Trilogy, #1)          50
# The Black Maria                                         50
# ...

# %%
result1.groupby(by=["Tittle","PRICES"]).count()
# Out:
# Empty DataFrame
# Columns: []
# Index: [(A Light in the Attic, £51.77), (It's Only the Himalayas, £45.17), (Libertarianism for Beginners, £51.33), (Mesaerion: The Best Science Fiction Stories 1800-1849, £37.59), (Olio, £23.88), (Our Band Could Be Your Life: Scenes from the American Indie Underground, 1981-1991, £57.25), (Rip it Up and Start Again, £35.02), (Sapiens: A Brief History of Humankind, £54.23), (Scott Pilgrim's Precious Little Life (Scott Pilgrim #1), £52.29), (Set Me Free, £17.46), (Shakespeare's Sonnets, £20.66), (Sharp Objects, £47.82), (Soumission, £50.10), (Starving Hearts (Triangular Trade Trilogy, #1), £13.99), (The Black Maria, £52.15), (The Boys in the Boat: Nine Americans and Their Epic Quest for Gold at the 1936 Berlin Olympics, £22.60), (The Coming Woman: A Novel Based on the Life of the Infamous Feminist, Victoria Woodhull, £17.93), (The Dirty Little Secrets of Getting Your Dream Job, £33.34), (The Requiem Red, £22.65), (Tipping the Velvet, £53.74)]

# %%
result1["PRICES"][0].replace("£","")
# Out:
# '51.77'

# %%
result1["PRICES"]=result2["PRICES"].astype("int")
result1["PRICES"]
# Out:
# 0      51
# 1      53
# 2      50
# 3      47
# 4      54
#        ..
# 995    57
# 996    23
# 997    37
# 998    51
# 999    45
# Name: PRICES, Length: 1000, dtype: int32

# %%
result1.describe()
# Out:
#             PRICES
# count  1000.000000
# mean     37.550000
# std      14.915427
# min      13.000000
# 25%      22.000000
# 50%      41.000000
# 75%      51.250000
# max      57.000000

# %%
#DATA VIZSUALIZATION

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
sns.countplot(result1["Tittle"])
# Out:
# C:\Users\HP\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Tittle', ylabel='count'>

# %%
sns.countplot(result1["PRICES"])
# Out:
# C:\Users\HP\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='PRICES', ylabel='count'>

# %%
sns.distplot(result1["PRICES"])
# Out:
# C:\Users\HP\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='PRICES', ylabel='Density'>

# %%
plt.pie(result1["PRICES"])
plt.legend()
plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
sns.boxplot("PRICES","Tittle",data=result1)
# Out:
# C:\Users\HP\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='PRICES', ylabel='Tittle'>

# %%
sns.violinplot(result1["PRICES"])
# Out:
# C:\Users\HP\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='PRICES'>

# %%
##FEATURE ENGINEERING
# Here we had the data on both Tittle of the Books and Prices
## Looking to prices most of the books only lie above 50 Dollars as we can seen clearly in violin plot or in the distribution plot

##CONCLUSION
## WE CAN CONCLUDE MOST OF THE POPULAR BOOKS ARE AVAILABLE ABOVE 50 DOLLARS AND BELOW 60 DOLLARS APPROXIMATELY
## ALL THE POPULAR BOOKS ARE AVAILABLE FROM 10 DOLLARS AND UPTO 60 DOLLARS
